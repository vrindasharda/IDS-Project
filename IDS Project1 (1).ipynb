# %% [markdown]
# # IDS Group Project: Wine Quality

# %% [markdown]
# ## About the project
# Our final aim is to be able to make prediction on the quality of wine given to us based on the parameters of our data set. We have labeled the qualities as 'bad', 'good', 'very good' and excellent'. And then we have used three algorithms namely Multiple Linear Regression, KNN and Decision Tree to predict the quality of the wine.

# %% [markdown]
# #### Report prepared by:
# * Kritika Aggarwal (18ucc039)
# * Anjali Toshniwal (18ucc070)
# * Vrinda Sharda (18ucc098)
# * Mehak Singhal (18ucc112)

# %% [markdown]
# #### Submitted to:
# * Dr. Sakthi Balan M
# * Dr. Subrat Dash
#
# for IDS course 2020 LNMIIT, Jaipur

# %% [markdown]
# ## Introduction
# The quality of wine is determined by a number of interrelated variables which take effect during the fermentation process. The variables that have the most significant effect are as follows; the pH of the wine, the temperature at which the fermentation process is transacted, the alcohol and CO2 percentage present post fermentation, the amount of SO2 (sulphur dioxide) present in the solution and the wines titratable acidity.
#
# The dynamics of the global wine industry are better understood through a brief history of wine as well as an overview of the wine making process. Some countries have longer historical and cultural ties with wine then others and that can affect the quality and perception of the product in the eyes of the consumer. Also, the conditions in which the wine grapes are raised and the processes used to make the wine can create a superior wine and therefore a competitive advantage.
#
# This project uses the wine quality data set of red wines of vinho verde. The literal translation for vinho verde is “green wine”, which means “young wine” with wine being released three to six months after the grapes are harvested.
#
#  Vinho verde is a reference to the wine produced in the northern region of Portugal and follows the regulations set by the Comissão de Viticultura da Região dos Vinhos Verdes (“Wine Commission of the Vinho Verde Region”).

# %% [markdown]
# ## About the Data Set:
# This data set has been taken from [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Wine+Quality) and is duly appreciated.
# This dataset consists of 1599 records with 12 features. The features represent several factors that might be useful in predicting the quality of the wine.
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Attributes
# The dataset consists of the following attributes:
#
# **1.	Fixed Acidity:** Most of the acids involved with wine are fixed acids and hence the acidity is fixed acidity.
#
# **2.	Volatile Acidity:** It is a measure of the wine's gaseous acids that contributes to the smell and taste of vinegar in wine.
#
# **3.	Citric Acid:** Citric acid is most commonly used as an acid supplement during the fermentation process to help winemakers boost the acidity of their wine especially grapes grown in warmer climates.
#
# **4.	Residual Sugar:** Residual sugar or 'RS' is the sugar from the grapes that's left over after fermentation. The more residual sugar remaining in a wine, the sweeter the wine is.
#
# **5.	Chlorides:** Wine contains from 2 to 4 g L–1 of salts of mineral acids, along with some organic acids, and they may have a key role on a potential salty taste of a wine, with chlorides being a major contributor to saltiness.
#
# **6.	Free Sulphur Dioxide:** Sulfur Dioxide is used throughout all stages of the winemaking process to prevent oxidation and microbial growth.
#
# **7.	Total Sulphur Dioxide:** Total Sulfur Dioxide (TSO2) is the portion of SO2 that is free in the wine plus the portion that is bound to other chemicals in the wine such as aldehydes, pigments etc.
#
# **8.	Density:** Density is the mass per unit volume of wine or must at 20°C. It is expressed in grams per milliliter, and denoted by the symbol ρ20°C.
#
# **9.	pH:** Most wine pH's fall around 3 or 4. About 3.3 to 3.6 is best for reds.
#
# **10.	Sulphates:** During wine making sulphur is used as an essential additive as it plays two important roles as an anti-oxidant and anti-microbial preservative in its free form.
#
# **11.	Alcohol:** Wine is an alcoholic drink typically made from fermented grape juice. Yeast consumes the sugar in the grapes and converts it to ethanol, carbon dioxide, and heat.
#
# Output variable based on sensory data:
#
# **12.	Quality:** It is our output attribute which rates the quality of our wine

# %% [markdown]
# ## Flow of the project

# %% [markdown]
# The plan for approaching this dataset shall be as follows:
# 1. First we will import the required libraries in our project. We need pandas for manipulation and analysis of data, numpy to be able to use mathematical functions, matpolib  for embedding plots into applications using general-purpose GUI toolkits and seaborn for drawing statistical graphs.
# 2. The second step will be to read the data, see its shape that is the dimensions.
# 3. Next we will do data handeling. For thst, we will first look for NULL values. If they exist we have to eliminate or replace them.
# 4. Then we will move to handling the outliers. We have to clean them as well so that they would not affect our result and our model.
# 5. After cleaning the data we shall start with the visualization. Using bar Graph we saw how our quality is distributed over our dataset. Then we made the correlation matrix to see the correlation between different attributes. And finally we plotted RegPlots to see how our attributes are correlated to the output.
# 6. In the next step we categorized our output into four levels. We will also normalize the data to get more accurate results.
# 7. Lastly, we will model the data using specific Machine Learning algorithms on the data set as per the requirements of the data and draw inferences using those results.

# %% [markdown]
# ## Importing libraries and Data

# %% [markdown]
#   ●	**pandas:** for manipulation and analysis of data.
#   ●	**numpy:**  contains a large collection of high-level mathematical functions to operate on large, arrays and matrices with multiple dimensions.
#   ●	**matplotlib:** for embedding plots into applications using general-purpose GUI toolkits.
#   ●	**seaborn:** for drawing attractive and informative statistical graphics.

# %%
#Importing the required Libraries
import numpy as np  
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Reading the Data
# A CSV file (Comma Separated Value File) is a type of plain text file but uses Comma To separate the tabular data. read_csv() is an important pandas function to read csv files.
# Using read_csv() we are directly reading our data from the site.
# Head() function is used to display the top 5 rows of our dataset.

# %%
#Reading the Data 
path="https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv"
WineData=pd.read_csv(path, sep=";")
# View first 5 entries of the dataset.
WineData.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# Using shape, we displayed the dimensions of the dataset:

# %%
#imensions of the data set
WineData.shape
# Out:
# (1599, 12)

# %% [markdown]
# Columns is used to display the attributes of the dataset.

# %%
#Attributes in the Data
WineData.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %% [markdown]
# ## Handeling the Data Set

# %% [markdown]
# **Data handling** is the process of securing the research data is gathered, archived or disposed of in a protected and safe way during and after the completion of the analysis process. Here we will check two types of ambiquities that might occur- NULL values and outliers.

# %% [markdown]
# ### Checking for NULL values

# %% [markdown]
# We will check for NULL values using heatMap. **A heat map (or heatmap)** is a data visualization technique that shows magnitude of a phenomenon as color in two dimensions.

# %%
#checking for NULL Values
sns.heatmap(WineData.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %% [markdown]
# As our heat map does not have colour variations we conclude that there are no NULL values. Thus, we proceed further.

# %% [markdown]
# ### Handeling Outliers

# %% [markdown]
# Outliers may contain valuable information or be meaningless aberrations caused by measurement and recording errors. In any case, they can cause problems with our results. Therefore it is very important to handle them. Here we make box plots for each attribute and drop the unnecessary outliers.

# %%
sns.boxplot('fixed acidity', data = WineData)

# %% [markdown]
# In correspondence to Fixed Acidity attribute we do have outliers but they are a lot. So, we cannot drop them as it would result in loosing a lot of data.

# %%
sns.boxplot('volatile acidity', data = WineData)

# %% [markdown]
# For Volatile Acidity we have dropped the outliers > 1.4.

# %%
WineData.drop(WineData['volatile acidity'][WineData['volatile acidity']>1.4].index, inplace=True)

# %%
sns.boxplot('citric acid', data = WineData)

# %% [markdown]
# Values of Citric Acid > 0.9 are dropped.

# %%
WineData.drop(WineData['citric acid'][WineData['citric acid']>0.9].index, inplace=True)

# %%
sns.boxplot('residual sugar', data = WineData)

# %% [markdown]
# residual sugar>15 are dropped.

# %%
WineData.drop(WineData['residual sugar'][WineData['citric acid']>15].index, inplace=True)

# %%
sns.boxplot('chlorides', data = WineData)

# %% [markdown]
# chlorides > 0.5 are considered as outliers and hence are dropped.

# %%
WineData.drop(WineData['chlorides'][WineData['chlorides']>0.5].index, inplace=True)

# %%
sns.boxplot('free sulfur dioxide', data = WineData)

# %% [markdown]
# As per similar reasons as Fixed Acidity free sulphur dioxide has no outliers.

# %%
sns.boxplot('total sulfur dioxide', data = WineData)

# %% [markdown]
# total sulfur dioxide > 250 are the outliers to be dropped.

# %%
WineData.drop(WineData['total sulfur dioxide'][WineData['total sulfur dioxide']>250].index, inplace=True)

# %%
sns.boxplot('density', data = WineData)

# %% [markdown]
# It is clearly evident from the plot, that there are no outlier to be dropped.

# %%
sns.boxplot('pH', data = WineData)

# %% [markdown]
# pH values < 2.8 and > 4 are to be dropped for being outliers.

# %%
WineData.drop(WineData['pH'][WineData['pH']>4].index, inplace=True)
WineData.drop(WineData['pH'][WineData['pH']<2.8].index, inplace=True)

# %%
sns.boxplot('sulphates', data = WineData)

# %% [markdown]
# sulphates>1.75 are dropped.

# %%
WineData.drop(WineData['sulphates'][WineData['sulphates']>1.75].index, inplace=True)

# %%
sns.boxplot('alcohol', data = WineData)

# %% [markdown]
# alcohol>14.5 are dropped values.

# %%
WineData.drop(WineData['alcohol'][WineData['alcohol']>14.4].index, inplace=True)

# %%
WineData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1588 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1588 non-null   float64
#  1   volatile acidity      1588 non-null   float64
#  2   citric acid           1588 non-null   float64
#  3   residual sugar        1588 non-null   float64
#  4   chlorides             1588 non-null   float64
#  5   free sulfur dioxide   1588 non-null   float64
#  6   total sulfur dioxide  1588 non-null   float64
#  7   density               1588 non-null   float64
#  8   pH                    1588 non-null   float64
#  9   sulphates             1588 non-null   float64
#  10  alcohol               1588 non-null   float64
#  11  quality               1588 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 161.3 KB

# %%
WineData.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1588.000000       1588.000000  1588.000000     1588.000000
# mean        8.319081          0.527434     0.269943        2.531455
# std         1.732766          0.177301     0.193089        1.392980
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.600000          1.330000     0.790000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1588.000000          1588.000000           1588.000000  1588.000000
# mean      0.086834            15.838161             45.997481     0.996754
# std       0.043339            10.452458             31.656469     0.001882
# ...

# %% [markdown]
# Pandas describe() is used to view some basic statistical details of the data like percentile, mean, std etc. Here we observe that the quality of wine ranges from 3 to 8.

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# **Data visualization** is the representation of data or information in a graph, chart, or other visual format. It communicates relationships of the data with images. This is important because :
# 1. It allows trends and patterns to be more easily seen.
# 2. A visual summary of information makes it easier to identify patterns and trends than looking through thousands of rows on a spreadsheet.
#
# Matplotlib, Seaborn, Bokeh, Altair, Plotly and ggplot are some libraries used for data visualization but we have used the initial two.

# %% [markdown]
# ### Quality Distribution

# %%
#Bar graph to see quality distribution of our dataset.
sns.countplot(WineData['quality'],label="Count")

# %% [markdown]
# Before predicting the quality of red wines, we need to understand the quality distribution. Notice that the distribution is highly disproportional: there are many more wines with qualities 5 and 6 than 3,4 and 8.

# %% [markdown]
# ### Correlation Matrix
# 1. The correlation matrix shows the correlation of all predictors in pairs.
# 2. The diagonal contains the variable names.
# 3. The correlation of two variables are in the intersection of the variables, rows and columns.
# 4. The colour intensity of the boxes and numbers indicate the correlation degree: strong colours indicate high correlation, whereas light colours indicate low correlation.

# %%
corr_matrix=WineData.corr()
fig, ax = plt.subplots(figsize=(12,12))
sns.heatmap(corr_matrix,annot=True,linewidths=.5, ax=ax)

# %% [markdown]
# Highly correlated features don’t add new information to the model and blurrs the effect of individual feature on the predictor and thus makes it difficult to explain effect of individual features on target feature. This problem is called **Multicollinearity**. As a general rule, we don’t want to keep features with very high correlation. So, we eliminate them using the function drop.
#
# Since fixed acidity, citric acid and density are highly corelated, they do not provide any extra information. So we drop citric acid and density. SImilarly free sulphur dioxide and total sulphur dioxide are highly co-realted, we drop the column free sulphur dioxide.

# %%
#Dropping the above stated attributes.
WineData.drop(['citric acid','density','free sulfur dioxide'],axis=1,inplace=True)

# %% [markdown]
# ### Regplots

# %% [markdown]
# **Reg Plots** are a kind of scatter plot only but the only and the major difference is that reg plots also provide us with a close fitted Regression line between the variables. They are used beacuse:
# 1. They give us a relationship between variables.
# 2. They tell us the strength of the correlation.
# 3. And also the direction of the relationship (positive, negative or weak relationship).

# %%
# Regplot to study individual attribute relationships with 'quality'.
left  = 0.1  # the left side of the subplots of the figure
right = 3    # the right side of the subplots of the figure
bottom = 0.1   # the bottom of the subplots of the figure
top = 1      # the top of the subplots of the figure
wspace = 0.3   # the amount of width reserved for blank space between subplots
hspace = 0.2   # the amount of height reserved for white space between subplots

f, axes = plt.subplots(1, 4)
plt.subplots_adjust(left, bottom, right, top, wspace, hspace)
sns.regplot('quality', 'chlorides', data = WineData,   ax=axes[0])
sns.regplot('quality', 'fixed acidity', data = WineData , ax=axes[1])
sns.regplot('quality', 'residual sugar', data = WineData, ax=axes[2])
sns.regplot('quality', 'total sulfur dioxide', data = WineData,  ax=axes[3])

f, axes = plt.subplots(1, 4)
plt.subplots_adjust(left, bottom, right, top, wspace, hspace)
sns.regplot('quality','pH', data = WineData, ax=axes[0])
sns.regplot('quality', 'sulphates', data = WineData, ax=axes[1])
sns.regplot('quality', 'alcohol', data = WineData, ax=axes[2])
sns.regplot('quality', 'volatile acidity', data = WineData, ax=axes[3])

# %% [markdown]
# By looking at the plots above, we can conclude the following:
# * We see a strong positive relation between alcohol and the quality of wine. This means the quantity of alcohol is directly determing the quality of red wine.
# * Sulphates and fixed acidity are also positively corelated to quality.
# * We observe strong negative relationship between volatile acidity and quality. Similarly total sulfurdioxide is also negatively corelated with the the quality of wine.
# * Weak correlation of quality can be seen with chlorides and pH.
# * It can be observed that residual sugar has almost 0 relation with the quality of red wine.

# %% [markdown]
# ### Labeling quality

# %% [markdown]
# There’s no clear distinction of quality levels among the predictors. Maybe grouping the quality values may help. Let’s denote bad quality for levels 0 to 3, good quality for levels 4 to 5, and very good quality for levels 6 to 7 and excellent quality for 8 and above. We shall add them as another column in our table as 'quality label'.

# %%
# Divide the 'quality' attribute for classifcation as bad=0, good=1, very good=2 and excellent=3.
WineData['quality label'] = WineData.quality.apply(lambda q: '0' if q <=3 else '1' if q <= 5 else '2' if q <= 7 else '3')

# %% [markdown]
# Now let us see how our data set finally looks.

# %%
WineData.head()
# Out:
#    fixed acidity  volatile acidity  residual sugar  chlorides  \
# 0            7.4              0.70             1.9      0.076
# 1            7.8              0.88             2.6      0.098
# 2            7.8              0.76             2.3      0.092
# 3           11.2              0.28             1.9      0.075
# 4            7.4              0.70             1.9      0.076
#
#    total sulfur dioxide    pH  sulphates  alcohol  quality quality label
# 0                  34.0  3.51       0.56      9.4        5             1
# 1                  67.0  3.20       0.68      9.8        5             1
# 2                  54.0  3.26       0.65      9.8        5             1
# 3                  60.0  3.16       0.58      9.8        6             2
# 4                  34.0  3.51       0.56      9.4        5             1

# %%
#Bar graph to see quality distribution of our dataset.
sns.countplot(WineData['quality label'],label="Count")

# %% [markdown]
# ## Normalization of the data
# Next, we will normalize the independent variables so as to reduce bias towards any particular variables. This is quite useful as the range of the variables are highly varied between the variables and name our independent variables x and target variable y. We will scale the values of all our independent variables to a range of 0-1. We will leave our target variable as is for convenience.

# %%
from sklearn import preprocessing
NewData=WineData[WineData.columns.drop("quality", "quality label")]
NormalizedData=preprocessing.minmax_scale(NewData)
DataResult=WineData["quality label"]

# %% [markdown]
# # Data Modelling

# %% [markdown]
# The process of modeling means training a machine learning algorithm to predict the labels from the features, tuning it for the business need, and validating it on holdout data.The output from modeling is a trained model that can be used for inference, making predictions on new data points. The various types of data modeling techniques include Single Predictor,Linear Regression, K-Nearest Neighbors(KNN), Decision Trees and many more . For our model we have used:
# **Linear Regression,
# Decision Trees,
# K-Nearest Neighbors**

# %% [markdown]
# And we have prepared our data as required, now, finally all we need to do is split the dataset into a training and testing dataset. The observations in the training set form the experience that the algorithm uses to learn whereas The test set is a set of observations used to evaluate the performance of the model using some performance metric.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(NormalizedData, DataResult, test_size=0.33, random_state=42)

# %% [markdown]
# ### Multiple Linear Regression

# %% [markdown]
# Multiple Linear regression approximates the multidimensional space of predictors X and outcomes Y into a function. The outcome, which is wine type, is categorical, so we need to convert to number before building the function.
# We want to build a model that for any predictor X, the algorithm predicts the class k, or wine type, with the largest conditional probability expressed by this equation:
# *Pr(Y=k|X1=x1…..,Xp=xp)  *
# Where Y is the outcome and p is the number of predictors.

# %% [markdown]
# since the attributes are independent and we also observe some linear patterns of attributes like sulphates, alcohol, volatile acidity, we apply multiple linear regression to out model.

# %%
from sklearn.linear_model import LinearRegression
clf= LinearRegression().fit(X_train,y_train)

# %% [markdown]
# We will take a look at the root mean square error of our model on the test set to have a better idea of the predicting power of the model after performing multiple linear regression.

# %% [markdown]
# #### Mean Square Error
#
# RMSE or Root mean square error is the sqare of variance of residuals.Root Mean Sqare Error is the standard deviation of the residuals (prediction errors).Residuals are a measure of how far Data points from the regression line
# It is a measure of how spread the residuals are and how much data is concentrated around the line of fit.

# %%
from sklearn.metrics import mean_squared_error
score1=clf.score(X_train, y_train)
print("R^2 =", score1)
a=clf.predict(X_train)
train_rmse= (mean_squared_error(a,y_train)) ** 0.5
print(train_rmse)
b=clf.predict(X_test)
test_rmse= (mean_squared_error(b,y_test)) ** 0.5
test_rmse
# Out:
# R^2 = 1.0
# 1.82912962053155e-15
# 1.8008988251641197e-15

# %% [markdown]
# The mean square error is 1.8008988251641197e-15. Now, lets calculate the R^2 score which (1-MSE). R^2 is literally the sqare of CORRELATION between X and y VARIABLES i.e Linear association between x and y VARIABLES.The values between -1 and +1.
#
# Here, R^2= 1.0. This means that our model fits perfectly.
#
# In Regression R^2 Regression Model tells about the amount of variability in y that is explained by the model.
# 100% indicates that the model explains all the variability of the response data around its mean. R^2 is the most common measure of of the over all model fitting procedure of a regression line used for predicting and forecasting.

# %% [markdown]
# ### Decision Tree Classifier

# %% [markdown]
# Decision trees are one of the most popularly used classification algorithms in the data science field.A decision tree is a flowchart-like structure in which each internal node represents a "test" on an attribute, each branch represents the outcome of the test, and each leaf node represents a class label (decision taken after computing all attributes).

# %% [markdown]
# Since attributes are independent, decision trees  would make a good classfication model.

# %%
from sklearn.tree import DecisionTreeClassifier
# Fit training data
classifier = DecisionTreeClassifier()
classifier.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# Now let us see, unsing sklearn, how decision tree classifier is dividing our data into 4 labels.

# %%
from sklearn import tree
fn=['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol']
cn=['bad', 'good', 'very good', 'excellent']
fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (4,4), dpi=300)
tree.plot_tree(classifier, feature_names = fn, class_names=cn, filled = True)
# Out:
# [Text(465.0, 755.0, 'pH <= 0.5\ngini = 0.514\nsamples = 1063\nvalue = [8, 478, 566, 11]\nclass = very good'),
#  Text(232.5, 453.0, 'pH <= 0.167\ngini = 0.032\nsamples = 486\nvalue = [8, 478, 0, 0]\nclass = good'),
#  Text(116.25, 151.0, 'gini = 0.0\nsamples = 8\nvalue = [8, 0, 0, 0]\nclass = bad'),
#  Text(348.75, 151.0, 'gini = 0.0\nsamples = 478\nvalue = [0, 478, 0, 0]\nclass = good'),
#  Text(697.5, 453.0, 'pH <= 0.833\ngini = 0.037\nsamples = 577\nvalue = [0, 0, 566, 11]\nclass = very good'),
#  Text(581.25, 151.0, 'gini = 0.0\nsamples = 566\nvalue = [0, 0, 566, 0]\nclass = very good'),
#  Text(813.75, 151.0, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 0, 11]\nclass = excellent')]

# %% [markdown]
# This plot nicely shows how decision tree classifier has divided the data into 4 different labels using **Gini Index** (The Gini coefficient og Gono Index is a single number aimed at measuring the degree of inequality in a distribution).

# %%
# Predict test data
y_pred = classifier.predict(X_test)

# %% [markdown]
# #### Confusion Matrix

# %% [markdown]
# The confusion matrix is a simple table with the cross tabulation of the predicted values with the actual observed values.
#
#
# All values are in absolute numbers of observations and predictions, so for example the True Positive is the number of predicted values that are exactly the same as the actual values.
# The meaning of the values in the table are:
# True Positive (TP): Predicted positive for an actual positive value.
# True Negative (TN): Predicted negative for an actual negative value.
# False Positive (FN) or Type 1 Error: Predicted positive for an actual negative value.
# False Negative (FN) or Type 2 Error: Predicted negative for an actual positive value
#
# Some useful statistic metrics can be calculated from the confusion matrix.
# Accuracy: the proportion of correct predictions for both positive and negative outcomes, i.e. the ability to correctly predict a positive and negative. High accuracy with a large difference in the number of positives and negatives becomes less meaningful, since the algorithm loses the ability to predict the less common class. In this case, other metrics complements the analysis.
#
# Accuracy : the proportion of correct predictions for both positive and negative outcomes, i.e. the ability to correctly predict a positive and negative.
# ![image8.PNG](attachment:image8.PNG)
#
# F1 Score: The F1 score is a measure of accuracy for classification problems with binary outcome. It is computed as the harmonic mean between precision and recall.
#
# ![image7.PNG](attachment:image7.PNG)
#
# Precision: is the probability of an actual positive occurs conditioned to a predicted positive result.
#
# ![image10.PNG](attachment:image10.PNG)
#
# Recall: is the same as sensitivity and is the probability of a predicted positive value conditioned to an actual positive value.
# ![image9.PNG](attachment:image9.PNG)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score  
c_m = confusion_matrix(y_test, y_pred)
print ("Confusion matrix\n", c_m,'\n')
ax=plt.matshow(c_m,cmap=plt.cm.GnBu)
print('Confusion matrix plot')
plt.colorbar(ax)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
print ("Classfication report")
print(classification_report(y_test, y_pred)) 
print ("Accuracy score")
print (accuracy_score(y_test,y_pred))
# Out:
# Confusion matrix
#  [[  1   0   0   0]
#  [  0 252   0   0]
#  [  0   0 265   0]
#  [  0   0   0   7]]
#
# Confusion matrix plot
# Classfication report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00       252
#            2       1.00      1.00      1.00       265
#            3       1.00      1.00      1.00         7
#
#     accuracy                           1.00       525
#    macro avg       1.00      1.00      1.00       525
# weighted avg       1.00      1.00      1.00       525
#
# Accuracy score
# 1.0

# %% [markdown]
# The figures show the confusion matrix by class support size (number of elements in each class). There are 7 intances on excellent wine, 265 instances of very good quality wine, 252 of good wine and 1 instance of bad quality wine. The confusion matrix shows the calculated accuracy and precission as 1 which means our model is very accurate.

# %% [markdown]
# ## KNN (K-Nearest Neighbours)
# The k-nearest neighbours algorithm estimates the conditional probability:
# *p(x1,..,xp)=Pr(Y=k|X1=x1,..,Xp=xp) *
# The algorithm calculates the Euclidean distance of all predictors, then for any point (x1,..,xp) in the multidimensional space that we want to predict, the algorithm determines the distance to k points. The k nearest points is refereed as neighbourhood.
# For k=1 the algorithm finds the distance to a single neighbour. For k equals to the number of samples, the algorithm uses all points. Hence, k is a tuning parameter that can be calculated running the algorithm for several values of k and picking the result for highest accuracy.

# %% [markdown]
# Since dataset is small and fully numerical, KNNs would be feasible and make a good choice as a classification model.

# %%
# value of k computed with cross validation scoring and precision
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
from sklearn import metrics 
ks=25
mean_acc=np.zeros((ks-1))
std_acc=np.zeros((ks-1))
confusionMx=[]
for n in range (1, ks):
    neigh=KNeighborsClassifier(n_neighbors=n).fit(X_train, y_train)
    yhat=neigh.predict(X_test)
    mean_acc[n-1]=metrics.accuracy_score(y_test, yhat)
    std_acc[n-1]=np.std(yhat==y_test)/np.sqrt(yhat.shape[0])
mean_acc
# Out:
# array([0.99619048, 0.99047619, 0.99047619, 0.98857143, 0.98857143,
#        0.98857143, 0.9847619 , 0.98285714, 0.98095238, 0.98095238,
#        0.98095238, 0.98095238, 0.98095238, 0.97904762, 0.97714286,
#        0.97904762, 0.97904762, 0.97714286, 0.97714286, 0.97714286,
#        0.97714286, 0.97904762, 0.97714286, 0.97904762])

# %%
plt.plot(range(1,ks),mean_acc,'g')
plt.ylabel('Accuracy')
plt.xlabel('Number of Neighbours=k')
plt.tight_layout()
plt.show()

# %% [markdown]
# Here we have taken the values of k from 1 to 25 and the highest accuracy is obtained at k = 1.

# %% [markdown]
# # Conclusion

# %% [markdown]
# This report used datasets of vinho verde red wine to predict the quality based on physicochemical properties.
# At the end we observed that the top 4 attributes on which the quality of the red wine is majorly dependent were:
# + *alcohol content*
# + *pH of the wine*
# + *sulphates content*
# + *volatile acidity of the wine*
#
# We modeled our data using 3 different algorithms and then checked their accuracy, which tured out to be vey high. Thus we were able to build models that predict the quality of wine and label them into 4 categories.

# %% [markdown]
# # References

# %% [markdown]
# * https://medium.com/deep-math-machine-learning-ai/chapter-4-decision-trees-algorithms-b93975f7a1f1
# * https://medium.com/@kirank.isme1820/white-wine-quality-prediction-928a36fc3df0
# * https://byjus.com/maths/data-sets/
# * https://en.wikipedia.org/wiki/Heat_map
# * https://www.geeksforgeeks.org/python-pandas-dataframe-describe-method/#:~:text=describe()%20method,-Last%20Updated%3A%2001&text=Pandas%20describe()%20is%20used,shown%20in%20the%20examples%20below.
# * https://www.import.io/post/what-is-data-visualization/
# * https://cxl.com/blog/outliers/#:~:text=Outliers%20may%20contain%20valuable%20information,to%20question%20and%20analyze%20outliers.
# * https://www.geeksforgeeks.org/python-seaborn-regplot-method/
# * https://towardsdatascience.com/visualizing-decision-trees-with-python-scikit-learn-graphviz-matplotlib-1c50b4aa68dc
